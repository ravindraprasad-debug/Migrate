# %% [markdown]
# # lakeflow connector alternate using script

# %% [markdown]
# #outlook direct read from attachment

# %%
# %pip install msal
dbutils.library.restartPython()

# %% [markdown]
# #decoding and ingesting to s3
